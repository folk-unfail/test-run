# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# Collecting pygit2==1.15.1
#   Downloading pygit2-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: cffi>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pygit2==1.15.1) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.16.0->pygit2==1.15.1) (2.22)
# Downloading pygit2-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 52.2 MB/s eta 0:00:00
# Installing collected packages: pygit2
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.17.0
#     Uninstalling pygit2-1.17.0:
#       Successfully uninstalled pygit2-1.17.0
# Successfully installed pygit2-1.15.1
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6725, done.
# remote: Counting objects: 100% (4/4), done.
# remote: Compressing objects: 100% (4/4), done.
# remote: Total 6725 (delta 2), reused 0 (delta 0), pack-reused 6721 (from 3)
# Receiving objects: 100% (6725/6725), 33.26 MiB | 18.13 MiB/s, done.
# Resolving deltas: 100% (3878/3878), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 8.06MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 8.04MB/s]
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/xl-to-v1_interposer-v4.0.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v4.0.safetensors
#
# 100% 5.40M/5.40M [00:00<00:00, 42.0MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_expansion.bin" to /content/Fooocus/models/prompt_expansion/fooocus_expansion/pytorch_model.bin
#
# 100% 335M/335M [00:01<00:00, 233MB/s]
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/juggernautXL_v8Rundiffusion.safetensors" to /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
#
# 100% 6.62G/6.62G [00:37<00:00, 188MB/s]
# Downloading: "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors" to /content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors
#
# 100% 47.3M/47.3M [00:00<00:00, 184MB/s]
# Total VRAM 15095 MB, total RAM 12979 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7865
# model_type EPS
# UNet ADM Dimension 2816
# Running on public URL: https://47f2ea260361b72650.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.logit_scale', 'cond_stage_model.clip_l.text_projection'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.48 seconds
# Base model loaded: /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
# VAE loaded: None
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.71 seconds
# 2025-02-08 16:59:33.340853: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1739033973.553217    1982 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1739033973.611461    1982 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-02-08 16:59:34.038950: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Started worker with PID 915
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://47f2ea260361b72650.gradio.live
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/sdxl_lightning_4step_lora.safetensors" to /content/Fooocus/models/loras/sdxl_lightning_4step_lora.safetensors
#
# 100% 376M/376M [00:09<00:00, 42.5MB/s]
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 3236982593774399754
# [Parameters] CFG = 1.0
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1), ('sdxl_lightning_4step_lora.safetensors', 1.0)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Loaded LoRA [/content/Fooocus/models/loras/sdxl_lightning_4step_lora.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 1.0.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 1.48 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Image processing ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 12.31 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.87 seconds
# 100% 4/4 [00:03<00:00,  1.33it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 8.09 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.14 seconds
# 100% 4/4 [00:01<00:00,  2.39it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.59 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 13.68 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 26.03 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.88 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 5844504720319758305
# [Parameters] CFG = 1.0
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.17 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Image processing ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 704)
# Preparation time: 0.50 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.58 seconds
# 100% 4/4 [00:01<00:00,  2.53it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 6.74 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.99 seconds
# 100% 4/4 [00:01<00:00,  2.56it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.11 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 11.84 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 12.38 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.96 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 5826414029454143179
# [Parameters] CFG = 1.0
# [Fooocus] Downloading upscale models ...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_upscaler_s409985e5.bin" to /content/Fooocus/models/upscale_models/fooocus_upscaler_s409985e5.bin
#
# 100% 32.1M/32.1M [00:00<00:00, 204MB/s]
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Image processing ...
# [Fooocus] Upscaling image from (704, 1344) ...
# Upscaling image with shape (1344, 704, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.38 seconds
# Final resolution is (1408, 2688).
# [Parameters] Denoising Strength = 0.382
# [Parameters] Initial Latent shape: torch.Size([1, 4, 336, 176])
# Preparation time: 31.73 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.34370481967926025, sigma_max = 1.1628645658493042
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.11 seconds
# 100% 4/4 [00:08<00:00,  2.02s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 53.69 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.34370481967926025, sigma_max = 1.1628645658493042
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.08 seconds
# 100% 4/4 [00:08<00:00,  2.09s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.31 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 54.33 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 108.02 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 139.84 seconds
# [Fooocus Model Management] Moving model(s) has taken 1.12 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 5778188734586984955
# [Parameters] CFG = 1.0
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Encoding positive #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 704)
# Preparation time: 0.55 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.69 seconds
# 100% 4/4 [00:01<00:00,  2.45it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.93 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.99 seconds
# 100% 4/4 [00:01<00:00,  2.39it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.37 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.49 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 11.42 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 12.00 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.85 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 3075520278253018445
# [Parameters] CFG = 1.0
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Encoding positive #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 704)
# Preparation time: 0.53 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.70 seconds
# 100% 4/4 [00:01<00:00,  2.49it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.98 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.06 seconds
# 100% 4/4 [00:01<00:00,  2.44it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.33 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.32 seconds
# [Fooocus] Processing enhance ...
# [Fooocus] VAE encoding ...
# Final resolution is (704, 1344).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.77 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.62 seconds
# 100% 4/4 [00:01<00:00,  2.44it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 8.35 seconds
# [Fooocus] VAE encoding ...
# Final resolution is (704, 1344).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.90 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.59 seconds
# 100% 4/4 [00:01<00:00,  2.42it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 8.58 seconds
# Processing time (total): 28.23 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 28.81 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.81 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 4245885346581862679
# [Parameters] CFG = 1.0
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.16 seconds
# [Fooocus] Encoding positive #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 704)
# Preparation time: 0.59 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.91 seconds
# 100% 4/4 [00:01<00:00,  2.43it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 6.24 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.01 seconds
# 100% 4/4 [00:01<00:00,  2.37it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.35 seconds
# [Fooocus] Processing enhance ...
# [Fooocus] VAE encoding ...
# Final resolution is (704, 1344).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.85 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.39970141649246216, sigma_max = 1.6155802011489868
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.77 seconds
# 100% 4/4 [00:01<00:00,  2.41it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 8.46 seconds
# [Fooocus] VAE encoding ...
# Final resolution is (704, 1344).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.80 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.39970141649246216, sigma_max = 1.6155802011489868
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.92 seconds
# 100% 4/4 [00:01<00:00,  2.39it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 8.80 seconds
# Processing time (total): 28.85 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 29.51 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.97 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 5936927498226584189
# [Parameters] CFG = 1.0
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 704)
# Preparation time: 0.53 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.56 seconds
# 100% 4/4 [00:01<00:00,  2.44it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.78 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.97 seconds
# 100% 4/4 [00:01<00:00,  2.41it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.32 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.44 seconds
# [Fooocus] Processing enhance ...
# [Fooocus] Downloading upscale models ...
# [Fooocus] Upscaling image from (704, 1344) ...
# Upscaling image with shape (1344, 704, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Final resolution is (1056, 2016).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 1.12 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.34370481967926025, sigma_max = 1.1628645658493042
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 2.40 seconds
# 100% 4/4 [00:04<00:00,  1.01s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 57.14 seconds
# [Fooocus] Downloading upscale models ...
# [Fooocus] Upscaling image from (704, 1344) ...
# Upscaling image with shape (1344, 704, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Final resolution is (1056, 2016).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.93 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.34370481967926025, sigma_max = 1.1628645658493042
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.56 seconds
# 100% 4/4 [00:04<00:00,  1.03s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 56.25 seconds
# Processing time (total): 124.62 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 125.20 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.73 seconds
# Loaded preset: /content/Fooocus/presets/lightning.json
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 3369682683364484227
# [Parameters] CFG = 1.0
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Request to load LoRAs [('sdxl_lightning_4step_lora.safetensors', 1.0)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sdxl_lightning_4step_lora.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 1.0.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 1.28 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 704)
# Preparation time: 1.69 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.55 seconds
# 100% 4/4 [00:01<00:00,  2.55it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.71 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.80 seconds
# 100% 4/4 [00:01<00:00,  2.50it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.36 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.09 seconds
# [Fooocus] Processing enhance ...
# [Fooocus] Downloading upscale models ...
# [Fooocus] Upscaling image from (704, 1344) ...
# Upscaling image with shape (1344, 704, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Final resolution is (1056, 2016).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 1.07 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.16 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.34370481967926025, sigma_max = 1.1628645658493042
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.67 seconds
# 100% 4/4 [00:04<00:00,  1.00s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 55.52 seconds
# [Fooocus] Downloading upscale models ...
# [Fooocus] Upscaling image from (704, 1344) ...
# Upscaling image with shape (1344, 704, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Final resolution is (1056, 2016).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.87 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.34370481967926025, sigma_max = 1.1628645658493042
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.36 seconds
# 100% 4/4 [00:04<00:00,  1.02s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 55.73 seconds
# Processing time (total): 122.04 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 123.78 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.74 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 538275532306545529
# [Parameters] CFG = 1.0
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Encoding positive #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 704)
# Preparation time: 0.27 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.45 seconds
# 100% 4/4 [00:01<00:00,  2.53it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.60 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.78 seconds
# 100% 4/4 [00:01<00:00,  2.51it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.35 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.04 seconds
# [Fooocus] Processing enhance ...
# [Fooocus] Downloading upscale models ...
# [Fooocus] Upscaling image from (704, 1344) ...
# Upscaling image with shape (1344, 704, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Final resolution is (1056, 2016).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.97 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.34370481967926025, sigma_max = 1.1628645658493042
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.55 seconds
# 100% 4/4 [00:04<00:00,  1.01s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 55.89 seconds
# [Fooocus] Downloading upscale models ...
# [Fooocus] Upscaling image from (704, 1344) ...
# Upscaling image with shape (1344, 704, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Final resolution is (1056, 2016).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.93 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.34370481967926025, sigma_max = 1.1628645658493042
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.37 seconds
# 100% 4/4 [00:04<00:00,  1.02s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 55.93 seconds
# Processing time (total): 122.46 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 122.77 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.73 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 5128764688984103673
# [Parameters] CFG = 1.0
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Encoding positive #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 704)
# Preparation time: 0.37 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.34 seconds
# 100% 4/4 [00:01<00:00,  2.45it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.34 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.58 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.71 seconds
# 100% 4/4 [00:01<00:00,  2.47it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 4.93 seconds
# [Fooocus] Processing enhance ...
# [Fooocus] Downloading upscale models ...
# [Fooocus] Upscaling image from (704, 1344) ...
# Upscaling image with shape (1344, 704, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Final resolution is (1056, 2016).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.84 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.34370481967926025, sigma_max = 1.1628645658493042
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.28 seconds
# 100% 4/4 [00:04<00:00,  1.01s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 54.71 seconds
# [Fooocus] Downloading upscale models ...
# [Fooocus] Upscaling image from (704, 1344) ...
# Upscaling image with shape (1344, 704, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Final resolution is (1056, 2016).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.82 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.34370481967926025, sigma_max = 1.1628645658493042
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.26 seconds
# 100% 4/4 [00:04<00:00,  1.02s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 55.23 seconds
# Processing time (total): 120.46 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 120.87 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.86 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 7528194162234055842
# [Parameters] CFG = 1.0
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 704)
# Preparation time: 0.25 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.40 seconds
# 100% 4/4 [00:01<00:00,  2.54it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.65 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.78 seconds
# 100% 4/4 [00:01<00:00,  2.54it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.34 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 4.93 seconds
# [Fooocus] Processing enhance ...
# [Fooocus] Downloading upscale models ...
# [Fooocus] Upscaling image from (704, 1344) ...
# Upscaling image with shape (1344, 704, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Final resolution is (1056, 2016).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.95 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.16 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.34370481967926025, sigma_max = 1.1628645658493042
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.43 seconds
# 100% 4/4 [00:03<00:00,  1.01it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 54.44 seconds
# [Fooocus] Downloading upscale models ...
# [Fooocus] Upscaling image from (704, 1344) ...
# Upscaling image with shape (1344, 704, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Final resolution is (1056, 2016).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.92 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.34370481967926025, sigma_max = 1.1628645658493042
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.37 seconds
# 100% 4/4 [00:04<00:00,  1.07s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 56.82 seconds
# Processing time (total): 121.83 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 122.14 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.76 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 6221597768139193249
# [Parameters] CFG = 1.0
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Fooocus] Encoding positive #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 704)
# ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.46 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.72 seconds
# 100% 4/4 [00:01<00:00,  2.48it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 4.94 seconds
# [Fooocus] Processing enhance ...
# [Fooocus] Downloading upscale models ...
# [Fooocus] Upscaling image from (704, 1344) ...
# Upscaling image with shape (1344, 704, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Final resolution is (1056, 2016).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.85 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.34370481967926025, sigma_max = 1.1628645658493042
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.28 seconds
# 100% 4/4 [00:04<00:00,  1.01s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 55.71 seconds
# [Fooocus] Downloading upscale models ...
# [Fooocus] Upscaling image from (704, 1344) ...
# Upscaling image with shape (1344, 704, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Final resolution is (1056, 2016).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 1.02 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.14 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.34370481967926025, sigma_max = 1.1628645658493042
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.62 seconds
# 100% 4/4 [00:04<00:00,  1.13s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 59.19 seconds
# Processing time (total): 125.30 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 125.81 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.80 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 5696599794092408887
# [Parameters] CFG = 1.0
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 704)
# Preparation time: 0.35 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.28 seconds
# 100% 4/4 [00:01<00:00,  2.38it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.52 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.72 seconds
# 100% 4/4 [00:01<00:00,  2.37it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.10 seconds
# [Fooocus] Processing enhance ...
# [Fooocus] Downloading upscale models ...
# [Fooocus] Upscaling image from (704, 1344) ...
# Upscaling image with shape (1344, 704, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Final resolution is (1056, 2016).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.84 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.34370481967926025, sigma_max = 1.1628645658493042
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.45 seconds
# 100% 4/4 [00:04<00:00,  1.06s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 57.35 seconds
# [Fooocus] Downloading upscale models ...
# [Fooocus] Upscaling image from (704, 1344) ...
# Upscaling image with shape (1344, 704, 3) ...
# Image upscaled.
# [Fooocus] VAE encoding ...
# Final resolution is (1056, 2016).
# [Fooocus] Preparing enhance prompts ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.94 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.34370481967926025, sigma_max = 1.1628645658493042
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.34 seconds
# 100% 4/4 [00:04<00:00,  1.06s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Enhancement image time: 57.02 seconds
# Processing time (total): 124.99 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 125.39 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.71 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 9020527705336975861
# [Parameters] CFG = 1.0
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Image processing ...
# [Vary] Image is resized because it is too small.
# [Fooocus] VAE encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.93 seconds
# Final resolution is (1024, 1024).
# [Parameters] Denoising Strength = 0.5
# [Parameters] Initial Latent shape: torch.Size([1, 4, 128, 128])
# Preparation time: 2.60 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.39970141649246216, sigma_max = 1.6155802011489868
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.69 seconds
# 100% 4/4 [00:01<00:00,  2.29it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.25 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.39970141649246216, sigma_max = 1.6155802011489868
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.78 seconds
# 100% 4/4 [00:01<00:00,  2.27it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.31 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.39 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 10.64 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 13.27 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.78 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 3450790405143482782
# [Parameters] CFG = 1.0
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Image processing ...
# [Vary] Image is resized because it is too small.
# [Fooocus] VAE encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.83 seconds
# Final resolution is (1024, 1024).
# [Parameters] Denoising Strength = 0.5
# [Parameters] Initial Latent shape: torch.Size([1, 4, 128, 128])
# Preparation time: 2.51 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.39970141649246216, sigma_max = 1.6155802011489868
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.71 seconds
# 100% 4/4 [00:01<00:00,  2.27it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.34 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.34 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.39970141649246216, sigma_max = 1.6155802011489868
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.76 seconds
# 100% 4/4 [00:01<00:00,  2.29it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 5.32 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 10.66 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 13.21 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.83 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 1420750727935474140
# [Parameters] CFG = 1.0
# [Fooocus] Downloading control models ...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/clip_vision_vit_h.safetensors" to /content/Fooocus/models/clip_vision/clip_vision_vit_h.safetensors
#
# 100% 1.84G/1.84G [00:25<00:00, 76.3MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_ip_negative.safetensors" to /content/Fooocus/models/controlnet/fooocus_ip_negative.safetensors
#
# 100% 64.1k/64.1k [00:00<00:00, 4.70MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/ip-adapter-plus_sdxl_vit-h.bin" to /content/Fooocus/models/controlnet/ip-adapter-plus_sdxl_vit-h.bin
#
# 100% 967M/967M [00:17<00:00, 57.9MB/s]
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Image processing ...
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.97 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.56 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1344, 704)
# Preparation time: 62.37 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 3.68 seconds
# 100% 4/4 [00:01<00:00,  2.23it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 8.25 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.72 seconds
# 100% 4/4 [00:01<00:00,  2.53it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-02-08/log.html
# Generating and saving time: 4.79 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 13.04 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 75.45 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.77 seconds
